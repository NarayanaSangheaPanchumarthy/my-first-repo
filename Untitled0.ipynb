# %% [markdown]
# 1.Hardware is the physical part of a computer system that you can touch, such as the keyboard or CPU.
# 2.Software is the set of programs and instructions that tell the hardware what to do, such as a web browser or a game.
